# %% [markdown]
# #### REAL WORLD PROBLEMS & ITS APPLICATIONS

# %% [markdown]
# * CUSTOMER CHURN ANALYSIS (CHURN MEANS LEAVING)

# %% [markdown]
# * Which transaction looks suspicious
#     * we'll use fraud detection

# %% [markdown]
# * Which product should be recommended
#     * recommendation model
