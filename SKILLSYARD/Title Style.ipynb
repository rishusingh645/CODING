# %%
from IPython.display import HTML, display

display(HTML("""
<style>
.skillsyard-header {
    background-color: #0D1117;
    color: #00C853;
    padding: 18px;
    border-radius: 12px;
    text-align: center;
    font-size: 38px;
    font-weight: bold;
    font-family: 'Poppins', sans-serif;
    border: 2px solid #00C853;
    box-shadow: 0px 0px 15px rgba(0,200,83,0.4);
}
</style>

<div class="skillsyard-header">
🚀 Functions
</div>
"""))
# Out:
# <style>
# .skillsyard-header {
#     background-color: #0D1117;
#     color: #00C853;
#     padding: 18px;
#     border-radius: 12px;
#     text-align: center;
#     font-size: 38px;
#     font-weight: bold;
#     font-family: 'Poppins', sans-serif;
#     border: 2px solid #00C853;
#     box-shadow: 0px 0px 15px rgba(0,200,83,0.4);
# }
# </style>
#
# <div class="skillsyard-header">
# 🚀 Functions
# </div>

# %%
from IPython.display import HTML, display

def topic(title):
    display(HTML(f"""
    <div style="
        background: linear-gradient(90deg,#1565C0,#42A5F5);
        color:white;
        padding:15px;
        border-radius:10px;
        font-size:32px;
        font-weight:bold;
        text-align:center;
        margin:10px 0;
    ">
        {title}
    </div>
    """))

# %%
topic("apply()")
# Out:
#     <div style="
#         background: linear-gradient(90deg,#1565C0,#42A5F5);
#         color:white;
#         padding:15px;
#         border-radius:10px;
#         font-size:32px;
#         font-weight:bold;
#         text-align:center;
#         margin:10px 0;
#     ">
#         apply()
#     </div>

# %%
topic("function()")
# Out:
#     <div style="
#         background: linear-gradient(90deg,#1565C0,#42A5F5);
#         color:white;
#         padding:15px;
#         border-radius:10px;
#         font-size:32px;
#         font-weight:bold;
#         text-align:center;
#         margin:10px 0;
#     ">
#         function()
#     </div>

# %%
from IPython.display import HTML, display

def topic(title):
    display(HTML(f"""
    <div style="
        background: linear-gradient(135deg,
    #0F172A 0%,
    #1E293B 40%,
    #00C853 100%
);
        color:white;
        padding:15px;
        border-radius:10px;
        font-size:32px;
        font-weight:bold;
        text-align:center;
        margin:10px 0;
    ">
        {title}
    </div>
    """))

# %%
topic("function()")
# Out:
#     <div style="
#         background: linear-gradient(135deg,
#     #0F172A 0%,
#     #1E293B 40%,
#     #00C853 100%
# );
#         color:white;
#         padding:15px;
#         border-radius:10px;
#         font-size:32px;
#         font-weight:bold;
#         text-align:center;
#         margin:10px 0;
#     ">
#         function()
#     </div>

# %%
from IPython.display import HTML, display

def topic(title):
    display(HTML(f"""
    <div style="
        background: linear-gradient(
    90deg,
    #0D1117 0%,
    #161B22 50%,
    #00E676 100%
);
        color:white;
        padding:15px;
        border-radius:10px;
        font-size:32px;
        font-weight:bold;
        text-align:center;
        margin:10px 0;
    ">
        {title}
    </div>
    """))

# %%
topic("function()")
# Out:
#     <div style="
#         background: linear-gradient(
#     90deg,
#     #0D1117 0%,
#     #161B22 50%,
#     #00E676 100%
# );
#         color:white;
#         padding:15px;
#         border-radius:10px;
#         font-size:32px;
#         font-weight:bold;
#         text-align:center;
#         margin:10px 0;
#     ">
#         function()
#     </div>

# %%
from IPython.display import HTML, display

def topic(title):
    display(HTML(f"""
    <div style="
       background: linear-gradient(
    135deg,
    #0B132B 0%,
    #1C2541 50%,
    #00C853 100%
);
        color:white;
        padding:15px;
        border-radius:10px;
        font-size:32px;
        font-weight:bold;
        text-align:center;
        margin:10px 0;
    ">
        {title}
    </div>
    """))

# %%
topic("function()")
# Out:
#     <div style="
#        background: linear-gradient(
#     135deg,
#     #0B132B 0%,
#     #1C2541 50%,
#     #00C853 100%
# );
#         color:white;
#         padding:15px;
#         border-radius:10px;
#         font-size:32px;
#         font-weight:bold;
#         text-align:center;
#         margin:10px 0;
#     ">
#         function()
#     </div>

# %%
from IPython.display import HTML, display

def topic(title):
    display(HTML(f"""
    <div style="
       background: linear-gradient(
    135deg,
    rgba(15,23,42,0.95),
    rgba(30,41,59,0.95),
    rgba(0,200,83,0.85)
);
        color:white;
        padding:15px;
        border-radius:10px;
        font-size:32px;
        font-weight:bold;
        text-align:center;
        margin:10px 0;
    ">
        {title}
    </div>
    """))

# %%
topic("function()")
# Out:
#     <div style="
#        background: linear-gradient(
#     135deg,
#     rgba(15,23,42,0.95),
#     rgba(30,41,59,0.95),
#     rgba(0,200,83,0.85)
# );
#         color:white;
#         padding:15px;
#         border-radius:10px;
#         font-size:32px;
#         font-weight:bold;
#         text-align:center;
#         margin:10px 0;
#     ">
#         function()
#     </div>

# %%
from IPython.display import HTML, display

def topic(title):
    display(HTML(f"""
    <div style="
       background: linear-gradient(
    135deg,
    #0F172A 0%,
    #1E293B 35%,
    #334155 70%,
    #00C853 100%
);
        color:white;
        padding:15px;
        border-radius:10px;
        font-size:32px;
        font-weight:bold;
        text-align:center;
        margin:10px 0;
    ">
        {title}
    </div>
    """))

# %%
topic("function()")
# Out:
#     <div style="
#        background: linear-gradient(
#     135deg,
#     #0F172A 0%,
#     #1E293B 35%,
#     #334155 70%,
#     #00C853 100%
# );
#         color:white;
#         padding:15px;
#         border-radius:10px;
#         font-size:32px;
#         font-weight:bold;
#         text-align:center;
#         margin:10px 0;
#     ">
#         function()
#     </div>

# %%
from IPython.display import HTML, display

display(HTML("""
<div style="
    background: linear-gradient(135deg,#0F172A,#1E293B,#00C853);
    color:white;
    padding:20px;
    border-radius:12px;
    text-align:center;
    font-size:40px;
    font-weight:bold;
    font-family:'Segoe UI';
    box-shadow:0 6px 20px rgba(0,0,0,0.25);
">
    🚀 Functions
</div>
"""))
# Out:
# <div style="
#     background: linear-gradient(135deg,#0F172A,#1E293B,#00C853);
#     color:white;
#     padding:20px;
#     border-radius:12px;
#     text-align:center;
#     font-size:40px;
#     font-weight:bold;
#     font-family:'Segoe UI';
#     box-shadow:0 6px 20px rgba(0,0,0,0.25);
# ">
#     🚀 Functions
# </div>

# %%
from IPython.display import HTML, display

display(HTML("""
<div style="
    background: linear-gradient(
    135deg,
    #00A651 0%,
    #00C853 50%,
    #69F0AE 100%
);
    color:white;
    padding:20px;
    border-radius:12px;
    text-align:center;
    font-size:40px;
    font-weight:bold;
    font-family:'Segoe UI';
    box-shadow:0 6px 20px rgba(0,0,0,0.25);
">
    🚀 Functions
</div>
"""))
# Out:
# <div style="
#     background: linear-gradient(
#     135deg,
#     #00A651 0%,
#     #00C853 50%,
#     #69F0AE 100%
# );
#     color:white;
#     padding:20px;
#     border-radius:12px;
#     text-align:center;
#     font-size:40px;
#     font-weight:bold;
#     font-family:'Segoe UI';
#     box-shadow:0 6px 20px rgba(0,0,0,0.25);
# ">
#     🚀 Functions
# </div>

# %%
from IPython.display import HTML, display

display(HTML("""
<div style="
    background: linear-gradient(
    135deg,
    #008F39 0%,
    #00C853 50%,
    #00E676 100%
);
    color:white;
    padding:20px;
    border-radius:12px;
    text-align:center;
    font-size:40px;
    font-weight:bold;
    font-family:'Segoe UI';
    box-shadow:0 6px 20px rgba(0,0,0,0.25);
">
    🚀 Functions
</div>
"""))
# Out:
# <div style="
#     background: linear-gradient(
#     135deg,
#     #008F39 0%,
#     #00C853 50%,
#     #00E676 100%
# );
#     color:white;
#     padding:20px;
#     border-radius:12px;
#     text-align:center;
#     font-size:40px;
#     font-weight:bold;
#     font-family:'Segoe UI';
#     box-shadow:0 6px 20px rgba(0,0,0,0.25);
# ">
#     🚀 Functions
# </div>

# %%
from IPython.display import HTML, display

display(HTML("""
<div style="
    background: linear-gradient(
    135deg,
    #00695C 0%,
    #00A651 40%,
    #00C853 70%,
    #B9F6CA 100%
);
    color:white;
    padding:20px;
    border-radius:12px;
    text-align:center;
    font-size:40px;
    font-weight:bold;
    font-family:'Segoe UI';
    box-shadow:0 6px 20px rgba(0,0,0,0.25);
">
    🚀 Functions
</div>
"""))
# Out:
# <div style="
#     background: linear-gradient(
#     135deg,
#     #00695C 0%,
#     #00A651 40%,
#     #00C853 70%,
#     #B9F6CA 100%
# );
#     color:white;
#     padding:20px;
#     border-radius:12px;
#     text-align:center;
#     font-size:40px;
#     font-weight:bold;
#     font-family:'Segoe UI';
#     box-shadow:0 6px 20px rgba(0,0,0,0.25);
# ">
#     🚀 Functions
# </div>

# %%
from IPython.display import HTML, display

display(HTML("""
<div style="
    background: linear-gradient(
    90deg,
    #00A651 0%,
    #00C853 35%,
    #00E676 70%,
    #69F0AE 100%
);
    color:white;
    padding:20px;
    border-radius:12px;
    text-align:center;
    font-size:40px;
    font-weight:bold;
    font-family:'Segoe UI';
    box-shadow:0 6px 20px rgba(0,0,0,0.25);
">
    🚀 Functions
</div>
"""))
# Out:
# <div style="
#     background: linear-gradient(
#     90deg,
#     #00A651 0%,
#     #00C853 35%,
#     #00E676 70%,
#     #69F0AE 100%
# );
#     color:white;
#     padding:20px;
#     border-radius:12px;
#     text-align:center;
#     font-size:40px;
#     font-weight:bold;
#     font-family:'Segoe UI';
#     box-shadow:0 6px 20px rgba(0,0,0,0.25);
# ">
#     🚀 Functions
# </div>

# %%
from IPython.display import HTML, display

display(HTML("""
<div style="
    background: linear-gradient(
    135deg,
    #00C853 0%,
    #00BCD4 50%,
    #1976D2 100%
);
    color:white;
    padding:20px;
    border-radius:12px;
    text-align:center;
    font-size:40px;
    font-weight:bold;
    font-family:'Segoe UI';
    box-shadow:0 6px 20px rgba(0,0,0,0.25);
">
    🚀 Functions
</div>
"""))
# Out:
# <div style="
#     background: linear-gradient(
#     135deg,
#     #00C853 0%,
#     #00BCD4 50%,
#     #1976D2 100%
# );
#     color:white;
#     padding:20px;
#     border-radius:12px;
#     text-align:center;
#     font-size:40px;
#     font-weight:bold;
#     font-family:'Segoe UI';
#     box-shadow:0 6px 20px rgba(0,0,0,0.25);
# ">
#     🚀 Functions
# </div>

# %%
from IPython.display import HTML, display

display(HTML("""
<div style="
    background: linear-gradient(
    90deg,
    #00E676 0%,
    #00B8D4 50%,
    #2979FF 100%
);
    color:white;
    padding:20px;
    border-radius:12px;
    text-align:center;
    font-size:40px;
    font-weight:bold;
    font-family:'Segoe UI';
    box-shadow:0 6px 20px rgba(0,0,0,0.25);
">
    🚀 Functions
</div>
"""))
# Out:
# <div style="
#     background: linear-gradient(
#     90deg,
#     #00E676 0%,
#     #00B8D4 50%,
#     #2979FF 100%
# );
#     color:white;
#     padding:20px;
#     border-radius:12px;
#     text-align:center;
#     font-size:40px;
#     font-weight:bold;
#     font-family:'Segoe UI';
#     box-shadow:0 6px 20px rgba(0,0,0,0.25);
# ">
#     🚀 Functions
# </div>

# %%
from IPython.display import HTML, display

display(HTML("""
<div style="
    background: linear-gradient(135deg,#00A651,#00C853,#2196F3);
    color:white;
    padding:20px;
    border-radius:15px;
    text-align:center;
    font-size:42px;
    font-weight:bold;
    font-family:'Segoe UI';
    box-shadow:0 6px 15px rgba(0,0,0,0.2);
">
    Functions
</div>
"""))
# Out:
# <div style="
#     background: linear-gradient(135deg,#00A651,#00C853,#2196F3);
#     color:white;
#     padding:20px;
#     border-radius:15px;
#     text-align:center;
#     font-size:42px;
#     font-weight:bold;
#     font-family:'Segoe UI';
#     box-shadow:0 6px 15px rgba(0,0,0,0.2);
# ">
#     Functions
# </div>
